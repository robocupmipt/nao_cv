# %%
import os
import cv2
from matplotlib import pyplot as plt

os.chdir(r'C:\nao_cv\geometrical\chessboard_images')

img = cv2.imread('109_53_1518_1558384235.8036860.jpg')

w = [0, 0, 0]
sh = img.shape

w[:2] = sh[:2]
plt.imshow(img)
print (sh)
print (w)

print (w[1::-1])
# Out:
# (480, 640, 3)
# [480, 640, 0]
# [640, 480]
