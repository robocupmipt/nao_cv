# %%
import cv2
import time
import numpy as np
import os
from os import listdir
from os.path import isfile, join
from matplotlib import pyplot as plt
from IPython.display import clear_output

# %run math_calibration.ipynb

arr = np.array

path = r'C:\nao_cv\geometrical\chessboard_images\\'

os.chdir(path)

size  = 38
shape = (7, 7)


files  = [f for f in listdir(path) if isfile(join(path, f))][::1]
photos = [x for x in files if (x[-4:] == '.jpg')]
strs   = [''.join([' ' if y == '_' else y for y in x]) for x in photos]
nums   = [[int(s) for s in x.split() if s.isdigit()][0] for x in strs]

frames = arr([dict(zip(['name', 'num'], x)) for x in arr([files, nums]).T])
frames = arr(sorted(frames, key = lambda k: int(k['num'])))


def text_data(frame, data):
    text = ''
    text += 'name:\n'
    text += '  %s\n' % (frame['name'])
    
    
    text += 'dist:  %s\n' % np.str(frame['num'])
            
        
    text += 'calc:\n'
    if (data == None):
        text += '  None\n'
    else:
        for i in range(len(data)):
            for key in data[i]:
                if (key not in ['opt_len', 'corners', 'optical']):
                    text += '  %s:  %s\n' % (key, np.str(np.around(data[i][key])))
            
    text += '\n'
    return text


import cv2
import time
import numpy as np
import os
from os import listdir
from os.path import isfile, join
from matplotlib import pyplot as plt
from IPython.display import clear_output


i = 680

image = cv2.imread(frames[i]['name'])
data  = calibration_data(image, shape, size)

k = 2.5
plt.figure(figsize=(4*k, 3*k))

text = text_data(frames[i], data)
plt.gcf().text(0.76, 0.5, text, fontsize=14)

plt.imshow(image)
# Out:
# ERROR:root:File `'math_calibration.ipynb.py'` not found.
# ca, cb, cc:  [42.46730523] [-2.45538059] [-0.50731004]
# p:  [[42.46730523 -1.18403946 -0.53206045]]
# q:
#  [[[-2.13162821e-14 -1.30650189e+02  0.00000000e+00]
#   [-6.66507603e+01 -1.35120141e+02 -1.07720452e+02]
#   [-8.97704629e+01  8.97704629e+01  0.00000000e+00]]]
# c:\program files (x86)\python37-32\lib\site-packages\ipykernel_launcher.py:231: RuntimeWarning: divide by zero encountered in double_scalars
# c:\program files (x86)\python37-32\lib\site-packages\ipykernel_launcher.py:231: RuntimeWarning: invalid value encountered in double_scalars

# %%
# Out:
# ca, cb, cc:  [42.46730523] [-2.45538059] [-0.50731004]
# c:\program files (x86)\python37-32\lib\site-packages\ipykernel_launcher.py:229: RuntimeWarning: divide by zero encountered in double_scalars
# c:\program files (x86)\python37-32\lib\site-packages\ipykernel_launcher.py:229: RuntimeWarning: invalid value encountered in double_scalars

# %%
i = 0
while (i <= len(frames)):
    
    clear_output()
    print ('iteration: ', i)
    
    
    k = 2.5
    plt.figure(figsize=(4*k, 3*k))
    
    image = cv2.imread(frames[i]['name'])
    data  = calibration_data(image, shape, size)
    
    text = text_data(frames[i], data)
    plt.gcf().text(0.76, 0.6, text, fontsize=14)
    
    plt.imshow(image)
    plt.show()
    
    key = input('Press fucking key: ')
    
    if (key == '1'):
        i -= 10
    else:
        i += 10
# Out:
# iteration:  680

# %%
250
# Out:
# asdf: a
# a
# <class 'str'>

# %%
# Out:
# ca, cb, cc:  [ 42.46730523 853.85281276] [-2.45538059  0.        ] [-0.50731004 -0.65756303]
# c:\program files (x86)\python37-32\lib\site-packages\ipykernel_launcher.py:229: RuntimeWarning: divide by zero encountered in double_scalars
# c:\program files (x86)\python37-32\lib\site-packages\ipykernel_launcher.py:229: RuntimeWarning: invalid value encountered in double_scalars
